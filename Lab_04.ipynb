# %% [markdown]
# <a href="https://colab.research.google.com/github/booty-bit/SU2021-ITSE-1429/blob/main/Lab_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def main():

  print("Welcome to Camel!")
  print("You have solen a camel to make your way across the great Mobi desert.")
  print("The natives want their camel back and are chasing you down! Survive your")
  print("desert trek and out run the natives.\n")

  # define variables
  done=False
  miles_traveled = 0
  thirst = 0
  camel_tiredness = 0
  natives_traveled = -20
  canteen = 3
  tracker = 0
  user = 0

  while done==False:
    oasis = random.randrange(1, 20)
    if oasis==1:
      print("\nLucky you, you just found an oasis! You refilled your canteen and your camel is rested!")
      thirst=0
      canteen=3
    print("""A. Drink from your canteen.
B. Ahead moderate speed.
C. Ahead full speed.
D. Stop for the night.
E. Status check.
Q. Quit.\n""")

    
    user_choice = input("What is your choice? ")

    # game logic follows 

    if user_choice.upper() == "Q":
      print("You have quit the game.")
      break
    elif user_choice.upper() == "E":
      print("\nYou have traveled: " + str(miles_traveled) + " miles.")
      print("You have " + str(canteen) + " drinks left ")
      print("The natives are " + str(miles_traveled - natives_traveled) + " miles behind you.\n")
    elif user_choice.upper() == "D":
      print("\nYou have stopped for the night to rest.")
      print("Your camel is rested and happy")
      camel_tiredness = 0
      natives_traveled = natives_traveled + random.randrange(7, 14)
      print("The natives are " +str(miles_traveled - natives_traveled) + " miles behind you.\n")
    elif user_choice.upper() == "C":
      print("\nYour camel runs like the wind")
      camel_tiredness = camel_tiredness + random.randrange (1,3)
      miles_traveled = miles_traveled + random.randrange (10,20)
      thirst = thirst + 1
      natives_traveled = natives_traveled + random.randrange (7,14)
      print("The natives are " + str(miles_traveled - natives_traveled) + " miles behind you.\n")
    elif user_choice.upper() == "B":
      thirst=thirst+1
      miles_traveled = miles_traveled + random.randrange(5, 12)
      camel_tiredness = camel_tiredness + 1
      natives_traveled = natives_traveled + random.randrange(7, 14)
      print("The natives are " +str(miles_traveled - natives_traveled) + " miles behind you.\n")
    elif user_choice.upper() == "A":
      if canteen>0:
        thirst=0
        canteen=canteen-1
        print("wish I had a soda pop, but this water is refreshing")
      else:
        print("\nyou have no drinks from canteen left\n")

    if thirst>6:
        print("You have died of thirst")
        done=True
        break
    elif thirst>4:
      print("\nYou are thirsty!\n")

    elif camel_tiredness>8:
      print("welp, camel died")
      done=True
      break
    if camel_tiredness>5:
      print("\nYour camel is getting tired\n")

    if miles_traveled<=-1:
      print("\nGAME OVER\n")
      done=True
      break

    tracker = miles_traveled - natives_traveled

    if tracker<=0:
      print("\nThe natives have caught up!")
      print("GAME OVER\n")
      done=True
      break

    if tracker<15 and done==False:
      print("\nThey're catching up to you\n")

    if miles_traveled>=200:
      print ("\nYou've done it, you win! You've outrun the natives!!\n")
      done=True
      break






main()
# Out:
# Welcome to Camel!
# You have solen a camel to make your way across the great Mobi desert.
# The natives want their camel back and are chasing you down! Survive your
# desert trek and out run the natives.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 28 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 33 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 39 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 48 miles behind you.
#
#
# Your camel is getting tired
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? d
#
# You have stopped for the night to rest.
# Your camel is rested and happy
# The natives are 35 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 39 miles behind you.
#
#
# You are thirsty!
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? a
# wish I had a soda pop, but this water is refreshing
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 38 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 38 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 43 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 46 miles behind you.
#
#
# Your camel is getting tired
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? d
#
# You have stopped for the night to rest.
# Your camel is rested and happy
# The natives are 34 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 42 miles behind you.
#
#
# You are thirsty!
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? a
# wish I had a soda pop, but this water is refreshing
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 45 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 51 miles behind you.
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 55 miles behind you.
#
#
# Your camel is getting tired
#
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? d
#
# You have stopped for the night to rest.
# Your camel is rested and happy
# The natives are 42 miles behind you.
#
#
# Lucky you, you just found an oasis! You refilled your canteen and your camel is rested!
# A. Drink from your canteen.
# B. Ahead moderate speed.
# C. Ahead full speed.
# D. Stop for the night.
# E. Status check.
# Q. Quit.
#
# What is your choice? c
#
# Your camel runs like the wind
# The natives are 48 miles behind you.
#
#
# You've done it, you win! You've outrun the natives!!

# %%
a
