# %% [markdown]
# <a href="https://colab.research.google.com/github/booty-bit/SU2021-ITSE-1429/blob/main/custom%20calculator%20b%20area%20of%20trapezoid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=20
b=14
h=10
c=(a+b)/2
area=c*h
print("The area is: ", area)
# Out:
# The area is:  170.0
